# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:99% !important; }</style>"))
# Out:
# /tmp/ipykernel_29841/956813560.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
# <style>.container { width:99% !important; }</style>

# %%
#chack for updated files\n,
# %load_ext autoreload
# %autoreload 2
#import packages
from __future__ import division

import numpy as np
import glob, json
import pickle
import os as os_pack
import matplotlib.pyplot as plt
import corner
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import healpy as hp
import os, glob, json, pickle
import matplotlib.pyplot as plt
import numpy as np
import scipy.linalg as sl
import enterprise
from enterprise.pulsar import Pulsar
import enterprise.signals.parameter as parameter
from enterprise.signals import utils
from enterprise.signals import signal_base
from enterprise.signals import selections
from enterprise.signals.selections import Selection
from enterprise.signals import white_signals
from enterprise.signals import gp_signals
from enterprise.signals import deterministic_signals
import enterprise.constants as const
from enterprise_extensions import blocks
from enterprise_extensions import models as ee_models
from enterprise_extensions import model_utils as ee_model_utils
from enterprise_extensions import model_orfs
from enterprise_extensions.hypermodel import HyperModel
from enterprise_extensions.frequentist import optimal_statistic as opt_stat
from enterprise_extensions import sampler as ee_sampler
from enterprise.signals.signal_base import LogLikelihood
#import enterprise_wavelets as models
from enterprise.signals.deterministic_signals import Deterministic
from enterprise.signals.parameter import function

from PTMCMCSampler.PTMCMCSampler import PTSampler as ptmcmc
import re
import sys
sys.path.append("/home/mitch/QuickBurstWork/QuickBurstChoStability/")
from QuickBurst import QuickBurst_MCMC as QuickBurst_MCMC
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
with open("/home/mitch/pulsar_data/15_year_data/psrs_trimmed_SNR99p.pkl", 'rb') as f:
    psrs_total = pickle.load(f)

# %%
noise_file_sim = "/home/mitch/pulsar_data/15year_data_pkl_quickburst/v1p1_all_dict.json"
with open(noise_file_sim, 'rb') as h:
    noise_params = json.load(h)
noise_params
# Out:
# {'B1855+09_430_ASP_efac': 1.115935306813982,
#  'B1855+09_430_ASP_log10_ecorr': -6.798122106550257,
#  'B1855+09_430_ASP_log10_t2equad': -7.564164330699591,
#  'B1855+09_430_PUPPI_efac': 1.000049037085653,
#  'B1855+09_430_PUPPI_log10_ecorr': -5.6989064141929715,
#  'B1855+09_430_PUPPI_log10_t2equad': -6.572540211467256,
#  'B1855+09_L-wide_ASP_efac': 1.043114017270374,
#  'B1855+09_L-wide_ASP_log10_ecorr': -6.120457109433745,
#  'B1855+09_L-wide_ASP_log10_t2equad': -6.517929916655293,
#  'B1855+09_L-wide_PUPPI_efac': 1.1118432332882,
#  'B1855+09_L-wide_PUPPI_log10_ecorr': -6.641667916624413,
#  'B1855+09_L-wide_PUPPI_log10_t2equad': -7.755603780476984,
#  'B1855+09_red_noise_gamma': 3.8866806405154866,
#  'B1855+09_red_noise_log10_A': -13.938023943317408,
#  'B1937+21_L-wide_ASP_efac': 2.584236583895852,
#  'B1937+21_L-wide_ASP_log10_ecorr': -6.985907827570632,
#  'B1937+21_L-wide_ASP_log10_t2equad': -7.240258825889674,
#  'B1937+21_L-wide_PUPPI_efac': 1.588553615548855,
#  'B1937+21_L-wide_PUPPI_log10_ecorr': -6.933190952449128,
#  'B1937+21_L-wide_PUPPI_log10_t2equad': -7.316718019537581,
#  'B1937+21_Rcvr1_2_GASP_efac': 1.11596238034839,
#  'B1937+21_Rcvr1_2_GASP_log10_ecorr': -6.951805082863183,
#  'B1937+21_Rcvr1_2_GASP_log10_t2equad': -7.078057247973833,
#  'B1937+21_Rcvr1_2_GUPPI_efac': 1.201231503643165,
#  'B1937+21_Rcvr1_2_GUPPI_log10_ecorr': -6.9742651134780225,
#  'B1937+21_Rcvr1_2_GUPPI_log10_t2equad': -7.239033824412098,
#  'B1937+21_Rcvr_800_GASP_efac': 2.54028984892031,
#  'B1937+21_Rcvr_800_GASP_log10_ecorr': -8.377559128584869,
#  'B1937+21_Rcvr_800_GASP_log10_t2equad': -7.101827347769447,
#  'B1937+21_Rcvr_800_GUPPI_efac': 3.97407135954626,
#  'B1937+21_Rcvr_800_GUPPI_log10_ecorr': -6.347443803757376,
#  'B1937+21_Rcvr_800_GUPPI_log10_t2equad': -7.196203648391603,
#  'B1937+21_S-wide_ASP_efac': 1.296147976316929,
#  'B1937+21_S-wide_ASP_log10_ecorr': -6.560243521577494,
#  'B1937+21_S-wide_ASP_log10_t2equad': -7.024684569470163,
#  'B1937+21_S-wide_PUPPI_efac': 1.116329734475017,
#  'B1937+21_S-wide_PUPPI_log10_ecorr': -6.998893530255561,
#  'B1937+21_S-wide_PUPPI_log10_t2equad': -7.170287594150795,
#  'B1937+21_red_noise_gamma': 4.551004266758053,
#  'B1937+21_red_noise_log10_A': -13.69093024601203,
#  'B1953+29_430_ASP_efac': 1.122265336810418,
#  'B1953+29_430_ASP_log10_ecorr': -6.801311233023301,
#  'B1953+29_430_ASP_log10_t2equad': -6.595969511606248,
#  'B1953+29_430_PUPPI_efac': 0.995563116988274,
#  'B1953+29_430_PUPPI_log10_ecorr': -5.068377030340542,
#  'B1953+29_430_PUPPI_log10_t2equad': -5.725665720895586,
#  'B1953+29_L-wide_ASP_efac': 1.085422949226532,
#  'B1953+29_L-wide_ASP_log10_ecorr': -7.668469566246393,
#  'B1953+29_L-wide_ASP_log10_t2equad': -8.399638557151581,
#  'B1953+29_L-wide_PUPPI_efac': 1.068074187050562,
#  'B1953+29_L-wide_PUPPI_log10_ecorr': -7.146306033798056,
#  'B1953+29_L-wide_PUPPI_log10_t2equad': -8.217718616702697,
#  'B1953+29_S-wide_ASP_efac': 1.153645740212544,
#  'B1953+29_S-wide_ASP_log10_ecorr': -6.709481100223183,
#  'B1953+29_S-wide_ASP_log10_t2equad': -6.429397872795122,
#  'B1953+29_red_noise_gamma': 2.793077624043318,
#  'B1953+29_red_noise_log10_A': -13.004421069091189,
#  'J0023+0923_430_ASP_efac': 1.101966732560332,
#  'J0023+0923_430_ASP_log10_ecorr': -6.82774000999425,
#  'J0023+0923_430_ASP_log10_t2equad': -8.379328374813772,
#  'J0023+0923_430_PUPPI_efac': 1.05440100253028,
#  'J0023+0923_430_PUPPI_log10_ecorr': -7.214804570153461,
#  'J0023+0923_430_PUPPI_log10_t2equad': -6.795146207080774,
#  'J0023+0923_L-wide_ASP_efac': 1.080482895771678,
#  'J0023+0923_L-wide_ASP_log10_ecorr': -7.825007013971638,
#  'J0023+0923_L-wide_ASP_log10_t2equad': -5.957285653521352,
#  'J0023+0923_L-wide_PUPPI_efac': 1.059064341365409,
#  'J0023+0923_L-wide_PUPPI_log10_ecorr': -7.592071908370426,
#  'J0023+0923_L-wide_PUPPI_log10_t2equad': -6.5764658901649335,
#  'J0023+0923_red_noise_gamma': 0.4582094332106858,
#  'J0023+0923_red_noise_log10_A': -13.298758385319621,
#  'J0030+0451_430_ASP_efac': 1.086189097591878,
#  'J0030+0451_430_ASP_log10_ecorr': -7.360892121475694,
#  'J0030+0451_430_ASP_log10_t2equad': -6.843236116084237,
#  'J0030+0451_430_PUPPI_efac': 1.05164891661052,
#  'J0030+0451_430_PUPPI_log10_ecorr': -6.848893061740094,
#  'J0030+0451_430_PUPPI_log10_t2equad': -6.92705934028527,
#  'J0030+0451_L-wide_ASP_efac': 1.125455392398476,
#  'J0030+0451_L-wide_ASP_log10_ecorr': -8.12433487010331,
#  'J0030+0451_L-wide_ASP_log10_t2equad': -7.131049926540358,
#  'J0030+0451_L-wide_PUPPI_efac': 1.04456044662113,
#  'J0030+0451_L-wide_PUPPI_log10_ecorr': -6.879539130463605,
#  'J0030+0451_L-wide_PUPPI_log10_t2equad': -7.827003713107375,
#  'J0030+0451_S-wide_PUPPI_efac': 1.00821083627619,
#  'J0030+0451_S-wide_PUPPI_log10_ecorr': -7.718654073334091,
#  'J0030+0451_S-wide_PUPPI_log10_t2equad': -6.903968227858332,
#  'J0030+0451_red_noise_gamma': 4.009012812150594,
#  'J0030+0451_red_noise_log10_A': -14.202025126236615,
#  'J0340+4130_Rcvr1_2_GUPPI_efac': 1.020420294732708,
#  'J0340+4130_Rcvr1_2_GUPPI_log10_ecorr': -8.294649393563315,
#  'J0340+4130_Rcvr1_2_GUPPI_log10_t2equad': -6.148311764744859,
#  'J0340+4130_Rcvr_800_GUPPI_efac': 1.021743296184682,
#  'J0340+4130_Rcvr_800_GUPPI_log10_ecorr': -6.226197491127485,
#  'J0340+4130_Rcvr_800_GUPPI_log10_t2equad': -5.983153311644942,
#  'J0340+4130_red_noise_gamma': 1.9786872033091054,
#  'J0340+4130_red_noise_log10_A': -16.25934340789635,
#  'J0406+3039_L-wide_PUPPI_efac': 1.023154430083455,
#  'J0406+3039_L-wide_PUPPI_log10_ecorr': -8.49987987653776,
#  'J0406+3039_L-wide_PUPPI_log10_t2equad': -6.593236143749284,
#  'J0406+3039_S-wide_PUPPI_efac': 1.034168701496937,
#  'J0406+3039_S-wide_PUPPI_log10_ecorr': -7.023391776348414,
#  'J0406+3039_S-wide_PUPPI_log10_t2equad': -7.3617615233002685,
#  'J0406+3039_red_noise_gamma': 2.445692914119723,
#  'J0406+3039_red_noise_log10_A': -15.61397244718639,
#  'J0437-4715_1.5GHz_YUPPI_efac': 5.36527942179416,
#  'J0437-4715_1.5GHz_YUPPI_log10_ecorr': -6.050068149718107,
#  'J0437-4715_1.5GHz_YUPPI_log10_t2equad': -9.132856483393196,
#  'J0437-4715_3GHz_YUPPI_efac': 1.39342336371275,
#  'J0437-4715_3GHz_YUPPI_log10_ecorr': -7.066726403554406,
#  'J0437-4715_3GHz_YUPPI_log10_t2equad': -8.509993302999595,
#  'J0437-4715_red_noise_gamma': 6.5930418409652995,
#  'J0437-4715_red_noise_log10_A': -18.096063536770448,
#  'J0509+0856_L-wide_PUPPI_efac': 1.095512521601887,
#  'J0509+0856_L-wide_PUPPI_log10_ecorr': -8.099210606541076,
#  'J0509+0856_L-wide_PUPPI_log10_t2equad': -7.503070389015834,
#  'J0509+0856_S-wide_PUPPI_efac': 1.059436607744737,
#  'J0509+0856_S-wide_PUPPI_log10_ecorr': -5.941548552371258,
#  'J0509+0856_S-wide_PUPPI_log10_t2equad': -5.721357983961399,
#  'J0509+0856_red_noise_gamma': 6.503617701514766,
#  'J0509+0856_red_noise_log10_A': -16.610071349282727,
#  'J0557+1551_L-wide_PUPPI_efac': 1.01682403184705,
#  'J0557+1551_L-wide_PUPPI_log10_ecorr': -7.365860105030853,
#  'J0557+1551_L-wide_PUPPI_log10_t2equad': -6.974993021474987,
#  'J0557+1551_S-wide_PUPPI_efac': 0.8350278479587,
#  'J0557+1551_S-wide_PUPPI_log10_ecorr': -7.705824622856606,
#  'J0557+1551_S-wide_PUPPI_log10_t2equad': -5.758501659438013,
#  'J0557+1551_red_noise_gamma': 0.2591062238787053,
#  'J0557+1551_red_noise_log10_A': -14.210775001455843,
#  'J0605+3757_Rcvr1_2_GUPPI_efac': 0.989610719476766,
#  'J0605+3757_Rcvr1_2_GUPPI_log10_ecorr': -5.510194903060417,
#  'J0605+3757_Rcvr1_2_GUPPI_log10_t2equad': -6.126732440466736,
#  'J0605+3757_Rcvr_800_GUPPI_efac': 0.955828093497542,
#  'J0605+3757_Rcvr_800_GUPPI_log10_ecorr': -8.379083187589488,
#  'J0605+3757_Rcvr_800_GUPPI_log10_t2equad': -5.644766723764354,
#  'J0605+3757_red_noise_gamma': 5.703894804549367,
#  'J0605+3757_red_noise_log10_A': -13.594288316447843,
#  'J0610-2100_Rcvr1_2_GUPPI_efac': 1.034109986652698,
#  'J0610-2100_Rcvr1_2_GUPPI_log10_ecorr': -6.444458664499393,
#  'J0610-2100_Rcvr1_2_GUPPI_log10_t2equad': -7.302484812749648,
#  'J0610-2100_Rcvr_800_GUPPI_efac': 1.020001032044076,
#  'J0610-2100_Rcvr_800_GUPPI_log10_ecorr': -6.266064392411721,
#  'J0610-2100_Rcvr_800_GUPPI_log10_t2equad': -5.899830011509388,
#  'J0610-2100_red_noise_gamma': 3.716487154079033,
#  'J0610-2100_red_noise_log10_A': -12.691253144495533,
#  'J0613-0200_Rcvr1_2_GASP_efac': 0.945813537708301,
#  'J0613-0200_Rcvr1_2_GASP_log10_ecorr': -6.677548427048339,
#  'J0613-0200_Rcvr1_2_GASP_log10_t2equad': -7.999344748962752,
#  'J0613-0200_Rcvr1_2_GUPPI_efac': 1.03153431040882,
#  'J0613-0200_Rcvr1_2_GUPPI_log10_ecorr': -6.797835586737512,
#  'J0613-0200_Rcvr1_2_GUPPI_log10_t2equad': -6.9582938987490035,
#  'J0613-0200_Rcvr_800_GASP_efac': 1.139281249281849,
#  'J0613-0200_Rcvr_800_GASP_log10_ecorr': -7.741807180440779,
#  'J0613-0200_Rcvr_800_GASP_log10_t2equad': -7.862390451357201,
#  'J0613-0200_Rcvr_800_GUPPI_efac': 1.104125819683603,
#  'J0613-0200_Rcvr_800_GUPPI_log10_ecorr': -6.86668666718751,
#  'J0613-0200_Rcvr_800_GUPPI_log10_t2equad': -6.665692566706781,
#  'J0613-0200_red_noise_gamma': 3.944740272547888,
#  'J0613-0200_red_noise_log10_A': -13.974337472824725,
#  'J0614-3329_Rcvr1_2_GUPPI_efac': 0.969206511032058,
#  'J0614-3329_Rcvr1_2_GUPPI_log10_ecorr': -7.824221129794299,
#  'J0614-3329_Rcvr1_2_GUPPI_log10_t2equad': -8.312053396673532,
#  'J0614-3329_Rcvr_800_GUPPI_efac': 0.970577707767909,
#  'J0614-3329_Rcvr_800_GUPPI_log10_ecorr': -6.16184836400461,
#  'J0614-3329_Rcvr_800_GUPPI_log10_t2equad': -6.683240603401466,
#  'J0636+5128_Rcvr1_2_GUPPI_efac': 1.04144694213213,
#  'J0636+5128_Rcvr1_2_GUPPI_log10_ecorr': -6.708688617307221,
#  'J0636+5128_Rcvr1_2_GUPPI_log10_t2equad': -7.6600451601375426,
#  'J0636+5128_Rcvr_800_GUPPI_efac': 1.00718182117215,
#  'J0636+5128_Rcvr_800_GUPPI_log10_ecorr': -6.741884522156617,
#  'J0636+5128_Rcvr_800_GUPPI_log10_t2equad': -7.723761547969633,
#  'J0636+5128_red_noise_gamma': 2.3435411458673525,
#  'J0636+5128_red_noise_log10_A': -16.91935912142078,
#  'J0645+5158_Rcvr1_2_GUPPI_efac': 1.0460600781108,
#  'J0645+5158_Rcvr1_2_GUPPI_log10_ecorr': -7.43388489865304,
#  'J0645+5158_Rcvr1_2_GUPPI_log10_t2equad': -8.456575264083892,
#  'J0645+5158_Rcvr_800_GUPPI_efac': 0.982255747275867,
#  'J0645+5158_Rcvr_800_GUPPI_log10_ecorr': -7.131266326059566,
#  'J0645+5158_Rcvr_800_GUPPI_log10_t2equad': -7.020748724220432,
#  'J0645+5158_red_noise_gamma': 0.6912237789361811,
#  'J0645+5158_red_noise_log10_A': -13.348167278583986,
#  'J0709+0458_L-wide_PUPPI_efac': 1.071868840969968,
#  'J0709+0458_L-wide_PUPPI_log10_ecorr': -8.068269297969929,
#  'J0709+0458_L-wide_PUPPI_log10_t2equad': -6.992237906576379,
#  'J0709+0458_S-wide_PUPPI_efac': 0.971307199058623,
#  'J0709+0458_S-wide_PUPPI_log10_ecorr': -5.635097300919934,
#  'J0709+0458_S-wide_PUPPI_log10_t2equad': -8.22905769095846,
#  'J0709+0458_red_noise_gamma': 3.5029407043208813,
#  'J0709+0458_red_noise_log10_A': -17.624143775320704,
#  'J0740+6620_Rcvr1_2_GUPPI_efac': 1.024528446754564,
#  'J0740+6620_Rcvr1_2_GUPPI_log10_ecorr': -6.90441354607899,
#  'J0740+6620_Rcvr1_2_GUPPI_log10_t2equad': -7.855182070214478,
#  'J0740+6620_Rcvr_800_GUPPI_efac': 1.013241968550914,
#  'J0740+6620_Rcvr_800_GUPPI_log10_ecorr': -6.727307025736905,
#  'J0740+6620_Rcvr_800_GUPPI_log10_t2equad': -7.177230853972957,
#  'J0740+6620_red_noise_gamma': 1.4924201677013311,
#  'J0740+6620_red_noise_log10_A': -17.413306619463793,
#  'J0931-1902_Rcvr1_2_GUPPI_efac': 0.997072476010111,
#  'J0931-1902_Rcvr1_2_GUPPI_log10_ecorr': -8.477686227070691,
#  'J0931-1902_Rcvr1_2_GUPPI_log10_t2equad': -6.797264621500389,
#  'J0931-1902_Rcvr_800_GUPPI_efac': 1.012975098054864,
#  'J0931-1902_Rcvr_800_GUPPI_log10_ecorr': -8.135817301413859,
#  'J0931-1902_Rcvr_800_GUPPI_log10_t2equad': -6.233904528767095,
#  'J0931-1902_red_noise_gamma': 5.602369096446976,
#  'J0931-1902_red_noise_log10_A': -15.929720315254674,
#  'J1012+5307_Rcvr1_2_GASP_efac': 1.02377099213393,
#  'J1012+5307_Rcvr1_2_GASP_log10_ecorr': -6.280245957371343,
#  'J1012+5307_Rcvr1_2_GASP_log10_t2equad': -8.39734111911683,
#  'J1012+5307_Rcvr1_2_GUPPI_efac': 1.0082567771699,
#  'J1012+5307_Rcvr1_2_GUPPI_log10_ecorr': -6.298206325479711,
#  'J1012+5307_Rcvr1_2_GUPPI_log10_t2equad': -7.4826899534952105,
#  'J1012+5307_Rcvr_800_GASP_efac': 1.0359835262533,
#  'J1012+5307_Rcvr_800_GASP_log10_ecorr': -8.319707883549723,
#  'J1012+5307_Rcvr_800_GASP_log10_t2equad': -6.032299586663788,
#  'J1012+5307_Rcvr_800_GUPPI_efac': 1.05174308155624,
#  'J1012+5307_Rcvr_800_GUPPI_log10_ecorr': -7.882094177234254,
#  'J1012+5307_Rcvr_800_GUPPI_log10_t2equad': -6.556050676873168,
#  'J1012+5307_red_noise_gamma': 0.6309966693091575,
#  'J1012+5307_red_noise_log10_A': -12.522985647730808,
#  'J1012-4235_Rcvr1_2_GUPPI_efac': 0.908898326867477,
#  'J1012-4235_Rcvr1_2_GUPPI_log10_ecorr': -7.124793921403631,
#  'J1012-4235_Rcvr1_2_GUPPI_log10_t2equad': -5.762881914146114,
#  'J1012-4235_Rcvr_800_GUPPI_efac': 0.746603343931311,
#  'J1012-4235_Rcvr_800_GUPPI_log10_ecorr': -6.300133965165754,
#  'J1012-4235_Rcvr_800_GUPPI_log10_t2equad': -5.195527095025685,
#  'J1012-4235_red_noise_gamma': 2.6130718818123504,
#  'J1012-4235_red_noise_log10_A': -12.800196982799909,
#  'J1022+1001_430_PUPPI_efac': 1.270131540717271,
#  'J1022+1001_430_PUPPI_log10_ecorr': -5.0035121389998904,
#  'J1022+1001_430_PUPPI_log10_t2equad': -5.750136062449421,
#  'J1022+1001_L-wide_PUPPI_efac': 1.084266251286681,
#  'J1022+1001_L-wide_PUPPI_log10_ecorr': -5.637856242532116,
#  'J1022+1001_L-wide_PUPPI_log10_t2equad': -6.962181273762461,
#  'J1022+1001_S-wide_PUPPI_efac': 1.162773948387633,
#  'J1022+1001_S-wide_PUPPI_log10_ecorr': -5.507915600397955,
#  'J1022+1001_S-wide_PUPPI_log10_t2equad': -8.290635842944523,
#  'J1022+1001_red_noise_gamma': 0.2983898679739191,
#  'J1022+1001_red_noise_log10_A': -12.150747092248933,
#  'J1024-0719_Rcvr1_2_GASP_efac': 0.925277144070335,
#  'J1024-0719_Rcvr1_2_GASP_log10_ecorr': -8.241744051119957,
#  'J1024-0719_Rcvr1_2_GASP_log10_t2equad': -6.36123329416105,
#  'J1024-0719_Rcvr1_2_GUPPI_efac': 1.010898974739695,
#  'J1024-0719_Rcvr1_2_GUPPI_log10_ecorr': -6.757777377776201,
#  'J1024-0719_Rcvr1_2_GUPPI_log10_t2equad': -7.722021915083889,
#  'J1024-0719_Rcvr_800_GASP_efac': 0.884345912098428,
#  'J1024-0719_Rcvr_800_GASP_log10_ecorr': -7.096546283908213,
#  'J1024-0719_Rcvr_800_GASP_log10_t2equad': -6.240578400179964,
#  'J1024-0719_Rcvr_800_GUPPI_efac': 1.00026172770671,
#  'J1024-0719_Rcvr_800_GUPPI_log10_ecorr': -7.662047633701905,
#  'J1024-0719_Rcvr_800_GUPPI_log10_t2equad': -8.109665589128504,
#  'J1024-0719_red_noise_gamma': 1.313174804647659,
#  'J1024-0719_red_noise_log10_A': -16.038697459503112,
#  'J1125+7819_Rcvr1_2_GUPPI_efac': 1.027220563995153,
#  'J1125+7819_Rcvr1_2_GUPPI_log10_ecorr': -8.372415610559424,
#  'J1125+7819_Rcvr1_2_GUPPI_log10_t2equad': -6.346478986790246,
#  'J1125+7819_Rcvr_800_GUPPI_efac': 1.030793729641,
#  'J1125+7819_Rcvr_800_GUPPI_log10_ecorr': -5.44973952164772,
#  'J1125+7819_Rcvr_800_GUPPI_log10_t2equad': -5.841323651051872,
#  'J1125+7819_red_noise_gamma': 3.61685969883854,
#  'J1125+7819_red_noise_log10_A': -16.40638014623718,
#  'J1312+0051_L-wide_PUPPI_efac': 1.049821716330424,
#  'J1312+0051_L-wide_PUPPI_log10_ecorr': -7.039634532232308,
#  'J1312+0051_L-wide_PUPPI_log10_t2equad': -6.178847787666479,
#  'J1312+0051_S-wide_PUPPI_efac': 0.969480309076556,
#  'J1312+0051_S-wide_PUPPI_log10_ecorr': -8.355982823987159,
#  'J1312+0051_S-wide_PUPPI_log10_t2equad': -5.56093065395025,
#  'J1312+0051_red_noise_gamma': 5.563110096965568,
#  'J1312+0051_red_noise_log10_A': -15.445935416945067,
#  'J1453+1902_430_PUPPI_efac': 0.968367628499376,
#  'J1453+1902_430_PUPPI_log10_ecorr': -5.052635529294617,
#  'J1453+1902_430_PUPPI_log10_t2equad': -7.485158199456939,
#  'J1453+1902_L-wide_PUPPI_efac': 1.087462175407255,
#  'J1453+1902_L-wide_PUPPI_log10_ecorr': -7.156882426415421,
#  'J1453+1902_L-wide_PUPPI_log10_t2equad': -6.103501507572114,
#  'J1453+1902_S-wide_PUPPI_efac': 1.054747222844056,
#  'J1453+1902_S-wide_PUPPI_log10_ecorr': -5.179947563879134,
#  'J1453+1902_S-wide_PUPPI_log10_t2equad': -5.488292763999967,
#  'J1453+1902_red_noise_gamma': 1.599648629894359,
#  'J1453+1902_red_noise_log10_A': -13.835496093856674,
#  'J1455-3330_Rcvr1_2_GASP_efac': 1.007572672521601,
#  'J1455-3330_Rcvr1_2_GASP_log10_ecorr': -5.852964977281282,
#  'J1455-3330_Rcvr1_2_GASP_log10_t2equad': -7.8163759665641415,
#  'J1455-3330_Rcvr1_2_GUPPI_efac': 1.037594323265469,
#  'J1455-3330_Rcvr1_2_GUPPI_log10_ecorr': -6.739680410405561,
#  'J1455-3330_Rcvr1_2_GUPPI_log10_t2equad': -7.73839812541615,
#  'J1455-3330_Rcvr_800_GASP_efac': 0.962674317546223,
#  'J1455-3330_Rcvr_800_GASP_log10_ecorr': -6.00001683345824,
#  'J1455-3330_Rcvr_800_GASP_log10_t2equad': -5.971742636274387,
#  'J1455-3330_Rcvr_800_GUPPI_efac': 0.98738811968536,
#  'J1455-3330_Rcvr_800_GUPPI_log10_ecorr': -6.06145782099319,
#  'J1455-3330_Rcvr_800_GUPPI_log10_t2equad': -8.311539965289855,
#  'J1455-3330_red_noise_gamma': 0.6002743573759041,
#  'J1455-3330_red_noise_log10_A': -17.23036781589139,
#  'J1600-3053_3GHz_YUPPI_efac': 1.026564530716887,
#  'J1600-3053_3GHz_YUPPI_log10_ecorr': -7.8336927517805695,
#  'J1600-3053_3GHz_YUPPI_log10_t2equad': -8.230199618961905,
#  'J1600-3053_Rcvr1_2_GASP_efac': 1.15191312052037,
#  'J1600-3053_Rcvr1_2_GASP_log10_ecorr': -6.752807270224575,
#  'J1600-3053_Rcvr1_2_GASP_log10_t2equad': -8.340723292844514,
#  'J1600-3053_Rcvr1_2_GUPPI_efac': 1.044273761386189,
#  'J1600-3053_Rcvr1_2_GUPPI_log10_ecorr': -6.8925274947807464,
#  'J1600-3053_Rcvr1_2_GUPPI_log10_t2equad': -8.05374969723697,
#  'J1600-3053_Rcvr_800_GASP_efac': 0.808705150972171,
#  'J1600-3053_Rcvr_800_GASP_log10_ecorr': -5.80526517050473,
#  'J1600-3053_Rcvr_800_GASP_log10_t2equad': -5.768987719871626,
#  'J1600-3053_Rcvr_800_GUPPI_efac': 1.05932832485913,
#  'J1600-3053_Rcvr_800_GUPPI_log10_ecorr': -6.095600977008153,
#  'J1600-3053_Rcvr_800_GUPPI_log10_t2equad': -6.324162266590475,
#  'J1600-3053_red_noise_gamma': 4.957518246113333,
#  'J1600-3053_red_noise_log10_A': -16.257430568637574,
#  'J1614-2230_Rcvr1_2_GASP_efac': 1.072699849038663,
#  'J1614-2230_Rcvr1_2_GASP_log10_ecorr': -7.7794534676251175,
#  'J1614-2230_Rcvr1_2_GASP_log10_t2equad': -8.053779126915263,
#  'J1614-2230_Rcvr1_2_GUPPI_efac': 1.035009007182931,
#  'J1614-2230_Rcvr1_2_GUPPI_log10_ecorr': -6.880885873579994,
#  'J1614-2230_Rcvr1_2_GUPPI_log10_t2equad': -8.202795546458434,
#  'J1614-2230_Rcvr_800_GASP_efac': 0.98879393445453,
#  'J1614-2230_Rcvr_800_GASP_log10_ecorr': -7.635309237970435,
#  'J1614-2230_Rcvr_800_GASP_log10_t2equad': -6.517933112474015,
#  'J1614-2230_Rcvr_800_GUPPI_efac': 1.017249655954617,
#  'J1614-2230_Rcvr_800_GUPPI_log10_ecorr': -7.045108375379001,
#  'J1614-2230_Rcvr_800_GUPPI_log10_t2equad': -8.487813148551705,
#  'J1614-2230_red_noise_gamma': 6.792927793172769,
#  'J1614-2230_red_noise_log10_A': -16.68499759618632,
#  'J1630+3734_Rcvr1_2_GUPPI_efac': 1.02456568525595,
#  'J1630+3734_Rcvr1_2_GUPPI_log10_ecorr': -7.49036457086721,
#  'J1630+3734_Rcvr1_2_GUPPI_log10_t2equad': -6.820956044221713,
#  'J1630+3734_Rcvr_800_GUPPI_efac': 1.03085132606649,
#  'J1630+3734_Rcvr_800_GUPPI_log10_ecorr': -6.32959200491962,
#  'J1630+3734_Rcvr_800_GUPPI_log10_t2equad': -6.308511513305433,
#  'J1630+3734_red_noise_gamma': 6.790092125992734,
#  'J1630+3734_red_noise_log10_A': -15.826234899944385,
#  'J1640+2224_430_ASP_efac': 1.121506029988498,
#  'J1640+2224_430_ASP_log10_ecorr': -8.330125942484548,
#  'J1640+2224_430_ASP_log10_t2equad': -6.28749904001143,
#  'J1640+2224_430_PUPPI_efac': 1.018935077105698,
#  'J1640+2224_430_PUPPI_log10_ecorr': -6.806961796818522,
#  'J1640+2224_430_PUPPI_log10_t2equad': -6.94392530310952,
#  'J1640+2224_L-wide_ASP_efac': 1.051346866559616,
#  'J1640+2224_L-wide_ASP_log10_ecorr': -6.397144367365945,
#  'J1640+2224_L-wide_ASP_log10_t2equad': -7.963353122720272,
#  'J1640+2224_L-wide_PUPPI_efac': 1.064966929963167,
#  'J1640+2224_L-wide_PUPPI_log10_ecorr': -6.3712376086431695,
#  'J1640+2224_L-wide_PUPPI_log10_t2equad': -7.839393249415642,
#  'J1640+2224_red_noise_gamma': 0.9361965830916703,
#  'J1640+2224_red_noise_log10_A': -14.710962629645477,
#  'J1643-1224_3GHz_YUPPI_efac': 1.00875861312875,
#  'J1643-1224_3GHz_YUPPI_log10_ecorr': -6.259837258302536,
#  'J1643-1224_3GHz_YUPPI_log10_t2equad': -5.88378170640433,
#  'J1643-1224_Rcvr1_2_GASP_efac': 1.055288197111588,
#  'J1643-1224_Rcvr1_2_GASP_log10_ecorr': -6.699173809101336,
#  'J1643-1224_Rcvr1_2_GASP_log10_t2equad': -7.04437827089935,
#  'J1643-1224_Rcvr1_2_GUPPI_efac': 1.068448071955812,
#  'J1643-1224_Rcvr1_2_GUPPI_log10_ecorr': -6.028355720079012,
#  'J1643-1224_Rcvr1_2_GUPPI_log10_t2equad': -6.303453370303317,
#  'J1643-1224_Rcvr_800_GASP_efac': 1.283631026364763,
#  'J1643-1224_Rcvr_800_GASP_log10_ecorr': -7.590286770947031,
#  'J1643-1224_Rcvr_800_GASP_log10_t2equad': -5.751242213387369,
#  'J1643-1224_Rcvr_800_GUPPI_efac': 1.18246926617779,
#  'J1643-1224_Rcvr_800_GUPPI_log10_ecorr': -5.609552950550871,
#  'J1643-1224_Rcvr_800_GUPPI_log10_t2equad': -6.0672686169524015,
#  'J1643-1224_red_noise_gamma': 1.0965529995262793,
#  'J1643-1224_red_noise_log10_A': -12.294098158593679,
#  'J1705-1903_Rcvr1_2_GUPPI_efac': 1.086667241043846,
#  'J1705-1903_Rcvr1_2_GUPPI_log10_ecorr': -7.135999518281587,
#  'J1705-1903_Rcvr1_2_GUPPI_log10_t2equad': -6.641914122602586,
#  'J1705-1903_Rcvr_800_GUPPI_efac': 1.086020351289511,
#  'J1705-1903_Rcvr_800_GUPPI_log10_ecorr': -6.550525074074865,
#  'J1705-1903_Rcvr_800_GUPPI_log10_t2equad': -7.41432279458265,
#  'J1705-1903_red_noise_gamma': 0.4055774455638343,
#  'J1705-1903_red_noise_log10_A': -11.879848779558715,
#  'J1713+0747_1.5GHz_YUPPI_efac': 1.073555321935761,
#  'J1713+0747_1.5GHz_YUPPI_log10_ecorr': -7.13933042231645,
#  'J1713+0747_1.5GHz_YUPPI_log10_t2equad': -8.428546212108444,
#  'J1713+0747_3GHz_YUPPI_efac': 1.043042188929558,
#  'J1713+0747_3GHz_YUPPI_log10_ecorr': -6.943356926251283,
#  'J1713+0747_3GHz_YUPPI_log10_t2equad': -8.104010444853724,
#  'J1713+0747_L-wide_ASP_efac': 0.977740209584478,
#  'J1713+0747_L-wide_ASP_log10_ecorr': -7.036467091841555,
#  'J1713+0747_L-wide_ASP_log10_t2equad': -7.914791656434374,
#  'J1713+0747_L-wide_PUPPI_efac': 0.929395884607325,
#  'J1713+0747_L-wide_PUPPI_log10_ecorr': -7.1265821259126065,
#  'J1713+0747_L-wide_PUPPI_log10_t2equad': -8.45422347829962,
#  'J1713+0747_Rcvr1_2_GASP_efac': 1.003503915930671,
#  'J1713+0747_Rcvr1_2_GASP_log10_ecorr': -6.7375785153259455,
#  'J1713+0747_Rcvr1_2_GASP_log10_t2equad': -7.080367640606891,
#  'J1713+0747_Rcvr1_2_GUPPI_efac': 1.001535976008163,
#  'J1713+0747_Rcvr1_2_GUPPI_log10_ecorr': -7.064266433523614,
#  'J1713+0747_Rcvr1_2_GUPPI_log10_t2equad': -8.453547347905747,
#  'J1713+0747_Rcvr_800_GASP_efac': 1.102212097122021,
#  'J1713+0747_Rcvr_800_GASP_log10_ecorr': -8.070405892459178,
#  'J1713+0747_Rcvr_800_GASP_log10_t2equad': -6.732852022971178,
#  'J1713+0747_Rcvr_800_GUPPI_efac': 1.036362877866851,
#  'J1713+0747_Rcvr_800_GUPPI_log10_ecorr': -6.825151876856516,
#  'J1713+0747_Rcvr_800_GUPPI_log10_t2equad': -7.105839604068173,
#  'J1713+0747_S-wide_ASP_efac': 1.039498912237716,
#  'J1713+0747_S-wide_ASP_log10_ecorr': -6.9446292268829035,
#  'J1713+0747_S-wide_ASP_log10_t2equad': -7.7120918503439935,
#  'J1713+0747_S-wide_PUPPI_efac': 1.059783958916402,
#  'J1713+0747_S-wide_PUPPI_log10_ecorr': -7.1053799964336335,
#  'J1713+0747_S-wide_PUPPI_log10_t2equad': -8.183890161581633,
#  'J1713+0747_red_noise_gamma': 3.081985030038712,
#  'J1713+0747_red_noise_log10_A': -16.066325048151608,
#  'J1719-1438_Rcvr1_2_GUPPI_efac': 0.999619579521779,
#  'J1719-1438_Rcvr1_2_GUPPI_log10_ecorr': -8.020036516352715,
#  'J1719-1438_Rcvr1_2_GUPPI_log10_t2equad': -8.456200771154878,
#  'J1719-1438_Rcvr_800_GUPPI_efac': 1.019957380238949,
#  'J1719-1438_Rcvr_800_GUPPI_log10_ecorr': -6.135614900376712,
#  'J1719-1438_Rcvr_800_GUPPI_log10_t2equad': -5.800563751939666,
#  'J1719-1438_red_noise_gamma': 6.628859831524863,
#  'J1719-1438_red_noise_log10_A': -16.19252911903118,
#  'J1730-2304_Rcvr1_2_GUPPI_efac': 1.02190537976774,
#  'J1730-2304_Rcvr1_2_GUPPI_log10_ecorr': -8.2720962228316,
#  'J1730-2304_Rcvr1_2_GUPPI_log10_t2equad': -7.392437342794547,
#  'J1730-2304_Rcvr_800_GUPPI_efac': 1.04426359076453,
#  'J1730-2304_Rcvr_800_GUPPI_log10_ecorr': -8.470279143415409,
#  'J1730-2304_Rcvr_800_GUPPI_log10_t2equad': -8.337983402893867,
#  'J1730-2304_red_noise_gamma': 5.615049413645516,
#  'J1730-2304_red_noise_log10_A': -14.981914038362886,
#  'J1738+0333_L-wide_ASP_efac': 1.02931232397878,
#  'J1738+0333_L-wide_ASP_log10_ecorr': -6.642098675094726,
#  'J1738+0333_L-wide_ASP_log10_t2equad': -7.78835329449323,
#  'J1738+0333_L-wide_PUPPI_efac': 1.046459356996636,
#  'J1738+0333_L-wide_PUPPI_log10_ecorr': -7.108563473461583,
#  'J1738+0333_L-wide_PUPPI_log10_t2equad': -7.559841018960891,
#  'J1738+0333_S-wide_ASP_efac': 1.073360443710119,
#  'J1738+0333_S-wide_ASP_log10_ecorr': -7.615294078576669,
#  'J1738+0333_S-wide_ASP_log10_t2equad': -7.558860570354262,
#  'J1738+0333_S-wide_PUPPI_efac': 1.030971357431065,
#  'J1738+0333_S-wide_PUPPI_log10_ecorr': -7.995038621278979,
#  'J1738+0333_S-wide_PUPPI_log10_t2equad': -7.279872050572727,
#  'J1738+0333_red_noise_gamma': 2.0126172236765716,
#  'J1738+0333_red_noise_log10_A': -13.544780709395424,
#  'J1741+1351_430_ASP_efac': 0.761312816607933,
#  'J1741+1351_430_ASP_log10_ecorr': -5.438338188959421,
#  'J1741+1351_430_ASP_log10_t2equad': -6.361655035033382,
#  'J1741+1351_430_PUPPI_efac': 1.002723587265366,
#  'J1741+1351_430_PUPPI_log10_ecorr': -6.288827484045192,
#  'J1741+1351_430_PUPPI_log10_t2equad': -6.493560891691296,
#  'J1741+1351_L-wide_ASP_efac': 1.048767675654976,
#  'J1741+1351_L-wide_ASP_log10_ecorr': -7.067739972016996,
#  'J1741+1351_L-wide_ASP_log10_t2equad': -7.928699886089866,
#  'J1741+1351_L-wide_PUPPI_efac': 1.0122187544429,
#  'J1741+1351_L-wide_PUPPI_log10_ecorr': -6.856800293210609,
#  'J1741+1351_L-wide_PUPPI_log10_t2equad': -7.419691332623539,
#  'J1741+1351_S-wide_ASP_efac': 0.948486370728789,
#  'J1741+1351_S-wide_ASP_log10_ecorr': -7.627324815806667,
#  'J1741+1351_S-wide_ASP_log10_t2equad': -7.36223048772661,
#  'J1741+1351_red_noise_gamma': 4.825619177076613,
#  'J1741+1351_red_noise_log10_A': -15.652396790148277,
#  'J1744-1134_Rcvr1_2_GASP_efac': 1.041688881559708,
#  'J1744-1134_Rcvr1_2_GASP_log10_ecorr': -6.381454939876926,
#  'J1744-1134_Rcvr1_2_GASP_log10_t2equad': -7.878580546851981,
#  'J1744-1134_Rcvr1_2_GUPPI_efac': 1.060110956243558,
#  'J1744-1134_Rcvr1_2_GUPPI_log10_ecorr': -6.623865764265868,
#  'J1744-1134_Rcvr1_2_GUPPI_log10_t2equad': -7.247518857738869,
#  'J1744-1134_Rcvr_800_GASP_efac': 1.062937426040929,
#  'J1744-1134_Rcvr_800_GASP_log10_ecorr': -6.43551507268861,
#  'J1744-1134_Rcvr_800_GASP_log10_t2equad': -6.2665061785496965,
#  'J1744-1134_Rcvr_800_GUPPI_efac': 1.044867292572697,
#  'J1744-1134_Rcvr_800_GUPPI_log10_ecorr': -6.4268747337077095,
#  'J1744-1134_Rcvr_800_GUPPI_log10_t2equad': -6.682781201127491,
#  'J1744-1134_red_noise_gamma': 4.363630251493152,
#  'J1744-1134_red_noise_log10_A': -14.430544574679868,
#  'J1745+1017_L-wide_PUPPI_efac': 1.234075844301581,
#  'J1745+1017_L-wide_PUPPI_log10_ecorr': -6.068789024376624,
#  'J1745+1017_L-wide_PUPPI_log10_t2equad': -6.05907210042327,
#  'J1745+1017_S-wide_PUPPI_efac': 1.11742827028034,
#  'J1745+1017_S-wide_PUPPI_log10_ecorr': -5.769898186175099,
#  'J1745+1017_S-wide_PUPPI_log10_t2equad': -8.027877952181385,
#  'J1745+1017_red_noise_gamma': 2.4625774319745424,
#  'J1745+1017_red_noise_log10_A': -11.742785263272056,
#  'J1747-4036_Rcvr1_2_GUPPI_efac': 1.010161767555524,
#  'J1747-4036_Rcvr1_2_GUPPI_log10_ecorr': -5.8584410499372765,
#  'J1747-4036_Rcvr1_2_GUPPI_log10_t2equad': -6.1624346140987,
#  'J1747-4036_Rcvr_800_GUPPI_efac': 1.030433442333827,
#  'J1747-4036_Rcvr_800_GUPPI_log10_ecorr': -5.495259035446506,
#  'J1747-4036_Rcvr_800_GUPPI_log10_t2equad': -7.6111504688739196,
#  'J1747-4036_red_noise_gamma': 2.684312721354293,
#  'J1747-4036_red_noise_log10_A': -12.461330476589973,
#  'J1751-2857_Rcvr1_2_GUPPI_efac': 1.021873191349063,
#  'J1751-2857_Rcvr1_2_GUPPI_log10_ecorr': -6.8634276543981185,
#  'J1751-2857_Rcvr1_2_GUPPI_log10_t2equad': -6.368248437359871,
#  'J1751-2857_Rcvr_800_GUPPI_efac': 0.74422702044922,
#  'J1751-2857_Rcvr_800_GUPPI_log10_ecorr': -7.508523553351919,
#  'J1751-2857_Rcvr_800_GUPPI_log10_t2equad': -5.014204015589805,
#  'J1751-2857_red_noise_gamma': 3.6789955618129904,
#  'J1751-2857_red_noise_log10_A': -13.228460529561078,
#  'J1802-2124_Rcvr1_2_GUPPI_efac': 1.06229421307509,
#  'J1802-2124_Rcvr1_2_GUPPI_log10_ecorr': -6.254357537515606,
#  'J1802-2124_Rcvr1_2_GUPPI_log10_t2equad': -6.0805778777071335,
#  'J1802-2124_Rcvr_800_GUPPI_efac': 1.06708813814473,
#  'J1802-2124_Rcvr_800_GUPPI_log10_ecorr': -5.379557720554441,
#  'J1802-2124_Rcvr_800_GUPPI_log10_t2equad': -8.3411746934053,
#  'J1802-2124_red_noise_gamma': 0.4172676682258413,
#  'J1802-2124_red_noise_log10_A': -12.080768146158137,
#  'J1811-2405_Rcvr1_2_GUPPI_efac': 1.003936783705143,
#  'J1811-2405_Rcvr1_2_GUPPI_log10_ecorr': -7.783925123907279,
#  'J1811-2405_Rcvr1_2_GUPPI_log10_t2equad': -8.098435432017435,
#  'J1811-2405_Rcvr_800_GUPPI_efac': 1.018856252937287,
#  'J1811-2405_Rcvr_800_GUPPI_log10_ecorr': -6.335172112638561,
#  'J1811-2405_Rcvr_800_GUPPI_log10_t2equad': -6.485785170529214,
#  'J1811-2405_red_noise_gamma': 1.6679555530990688,
#  'J1811-2405_red_noise_log10_A': -16.7742688195429,
#  'J1832-0836_Rcvr1_2_GUPPI_efac': 1.011904216608224,
#  'J1832-0836_Rcvr1_2_GUPPI_log10_ecorr': -8.08957007290632,
#  'J1832-0836_Rcvr1_2_GUPPI_log10_t2equad': -8.463059620463866,
#  'J1832-0836_Rcvr_800_GUPPI_efac': 1.013857153290994,
#  'J1832-0836_Rcvr_800_GUPPI_log10_ecorr': -6.365499008496004,
#  'J1832-0836_Rcvr_800_GUPPI_log10_t2equad': -6.394981063718822,
#  'J1832-0836_red_noise_gamma': 1.89814742981676,
#  'J1832-0836_red_noise_log10_A': -17.21395336565346,
#  'J1843-1113_Rcvr1_2_GUPPI_efac': 1.00890289710252,
#  'J1843-1113_Rcvr1_2_GUPPI_log10_ecorr': -7.725554095866707,
#  'J1843-1113_Rcvr1_2_GUPPI_log10_t2equad': -6.8737124045440146,
#  'J1843-1113_Rcvr_800_GUPPI_efac': 1.035778613666703,
#  'J1843-1113_Rcvr_800_GUPPI_log10_ecorr': -6.829975642706282,
#  'J1843-1113_Rcvr_800_GUPPI_log10_t2equad': -8.300911783274136,
#  'J1843-1113_red_noise_gamma': 0.20514228773885862,
#  'J1843-1113_red_noise_log10_A': -14.741928338477088,
#  'J1853+1303_430_ASP_efac': 1.070030692601155,
#  'J1853+1303_430_ASP_log10_ecorr': -6.236851738689241,
#  'J1853+1303_430_ASP_log10_t2equad': -7.530680773232424,
#  'J1853+1303_430_PUPPI_efac': 0.991703599205472,
#  'J1853+1303_430_PUPPI_log10_ecorr': -6.46267507975514,
#  'J1853+1303_430_PUPPI_log10_t2equad': -6.048172259665166,
#  'J1853+1303_L-wide_ASP_efac': 1.04081229080131,
#  'J1853+1303_L-wide_ASP_log10_ecorr': -5.9604852698547806,
#  'J1853+1303_L-wide_ASP_log10_t2equad': -7.037853343180932,
#  'J1853+1303_L-wide_PUPPI_efac': 1.020261833432291,
#  'J1853+1303_L-wide_PUPPI_log10_ecorr': -8.465378445977182,
#  'J1853+1303_L-wide_PUPPI_log10_t2equad': -7.3434423931159305,
#  'J1853+1303_red_noise_gamma': 2.186811772401027,
#  'J1853+1303_red_noise_log10_A': -13.465171590411858,
#  'J1903+0327_3GHz_YUPPI_efac': 0.871595413728467,
#  'J1903+0327_3GHz_YUPPI_log10_ecorr': -6.816635763243166,
#  'J1903+0327_3GHz_YUPPI_log10_t2equad': -6.57242538059288,
#  'J1903+0327_L-wide_ASP_efac': 1.13113677472928,
#  'J1903+0327_L-wide_ASP_log10_ecorr': -5.778097887298083,
#  'J1903+0327_L-wide_ASP_log10_t2equad': -8.140953212065678,
#  'J1903+0327_L-wide_PUPPI_efac': 1.150509206583629,
#  'J1903+0327_L-wide_PUPPI_log10_ecorr': -5.597851203701663,
#  'J1903+0327_L-wide_PUPPI_log10_t2equad': -8.4596317009019,
#  'J1903+0327_S-wide_ASP_efac': 0.635997833999066,
#  'J1903+0327_S-wide_ASP_log10_ecorr': -6.710856826201565,
#  'J1903+0327_S-wide_ASP_log10_t2equad': -5.616455335583583,
#  'J1903+0327_S-wide_PUPPI_efac': 1.084147687483405,
#  'J1903+0327_S-wide_PUPPI_log10_ecorr': -6.306711597226368,
#  'J1903+0327_S-wide_PUPPI_log10_t2equad': -7.442422871063594,
#  'J1903+0327_red_noise_gamma': 1.8225960071824103,
#  'J1903+0327_red_noise_log10_A': -12.219946384657113,
#  'J1909-3744_3GHz_YUPPI_efac': 0.993414867424727,
#  'J1909-3744_3GHz_YUPPI_log10_ecorr': -7.1269475247257885,
#  'J1909-3744_3GHz_YUPPI_log10_t2equad': -8.477203673578732,
#  'J1909-3744_Rcvr1_2_GASP_efac': 0.92977258686995,
#  'J1909-3744_Rcvr1_2_GASP_log10_ecorr': -8.355716473093485,
#  'J1909-3744_Rcvr1_2_GASP_log10_t2equad': -7.22057220353736,
#  'J1909-3744_Rcvr1_2_GUPPI_efac': 1.032683790875997,
#  'J1909-3744_Rcvr1_2_GUPPI_log10_ecorr': -7.164174373013931,
#  'J1909-3744_Rcvr1_2_GUPPI_log10_t2equad': -8.035773123087116,
#  'J1909-3744_Rcvr_800_GASP_efac': 1.006459805227822,
#  'J1909-3744_Rcvr_800_GASP_log10_ecorr': -7.307757230245945,
#  'J1909-3744_Rcvr_800_GASP_log10_t2equad': -6.851446248951442,
#  'J1909-3744_Rcvr_800_GUPPI_efac': 1.024392205051981,
#  'J1909-3744_Rcvr_800_GUPPI_log10_ecorr': -7.281270697715134,
#  'J1909-3744_Rcvr_800_GUPPI_log10_t2equad': -7.40691946573309,
#  'J1909-3744_red_noise_gamma': 3.3275893149106897,
#  'J1909-3744_red_noise_log10_A': -17.402908202358645,
#  'J1910+1256_L-wide_ASP_efac': 1.0353426701626,
#  'J1910+1256_L-wide_ASP_log10_ecorr': -7.168306572035723,
#  'J1910+1256_L-wide_ASP_log10_t2equad': -8.292014213904844,
#  'J1910+1256_L-wide_PUPPI_efac': 1.04221444890355,
#  'J1910+1256_L-wide_PUPPI_log10_ecorr': -6.338144232834369,
#  'J1910+1256_L-wide_PUPPI_log10_t2equad': -8.23477305462413,
#  'J1910+1256_S-wide_ASP_efac': 0.928974326712794,
#  'J1910+1256_S-wide_ASP_log10_ecorr': -6.2718727283287246,
#  'J1910+1256_S-wide_ASP_log10_t2equad': -6.105215867513536,
#  'J1910+1256_S-wide_PUPPI_efac': 1.02941290829992,
#  'J1910+1256_S-wide_PUPPI_log10_ecorr': -6.505855693275123,
#  'J1910+1256_S-wide_PUPPI_log10_t2equad': -7.459847556702073,
#  'J1910+1256_red_noise_gamma': 1.2579665222284724,
#  'J1910+1256_red_noise_log10_A': -15.730268421786711,
#  'J1911+1347_430_PUPPI_efac': 0.921463776212665,
#  'J1911+1347_430_PUPPI_log10_ecorr': -5.690192014234225,
#  'J1911+1347_430_PUPPI_log10_t2equad': -5.575255021535984,
#  'J1911+1347_L-wide_PUPPI_efac': 1.02034979144507,
#  'J1911+1347_L-wide_PUPPI_log10_ecorr': -8.368585474115248,
#  'J1911+1347_L-wide_PUPPI_log10_t2equad': -7.527731465538314,
#  'J1911+1347_red_noise_gamma': 3.8660232224399653,
#  'J1911+1347_red_noise_log10_A': -16.70876920736361,
#  'J1918-0642_Rcvr1_2_GASP_efac': 1.000039492448609,
#  'J1918-0642_Rcvr1_2_GASP_log10_ecorr': -7.825040199978874,
#  'J1918-0642_Rcvr1_2_GASP_log10_t2equad': -8.05239014723718,
#  'J1918-0642_Rcvr1_2_GUPPI_efac': 1.003511177590823,
#  'J1918-0642_Rcvr1_2_GUPPI_log10_ecorr': -6.69481565895366,
#  'J1918-0642_Rcvr1_2_GUPPI_log10_t2equad': -6.855296864739584,
#  'J1918-0642_Rcvr_800_GASP_efac': 1.033646426480592,
#  'J1918-0642_Rcvr_800_GASP_log10_ecorr': -7.2021045326313535,
#  'J1918-0642_Rcvr_800_GASP_log10_t2equad': -6.370619125322411,
#  'J1918-0642_Rcvr_800_GUPPI_efac': 1.006897286585479,
#  'J1918-0642_Rcvr_800_GUPPI_log10_ecorr': -6.751006277563872,
#  'J1918-0642_Rcvr_800_GUPPI_log10_t2equad': -6.477713213672427,
#  'J1918-0642_red_noise_gamma': 0.8048926452845986,
#  'J1918-0642_red_noise_log10_A': -15.533531190730118,
#  'J1923+2515_430_ASP_efac': 1.5538805584867,
#  'J1923+2515_430_ASP_log10_ecorr': -6.162863458997219,
#  'J1923+2515_430_ASP_log10_t2equad': -6.860894462268968,
#  'J1923+2515_430_PUPPI_efac': 1.005847184515789,
#  'J1923+2515_430_PUPPI_log10_ecorr': -6.344730571593688,
#  'J1923+2515_430_PUPPI_log10_t2equad': -8.150280691995459,
#  'J1923+2515_L-wide_ASP_efac': 0.890192966284531,
#  'J1923+2515_L-wide_ASP_log10_ecorr': -6.384763653739999,
#  'J1923+2515_L-wide_ASP_log10_t2equad': -7.269836380119906,
#  'J1923+2515_L-wide_PUPPI_efac': 1.062431093664011,
#  'J1923+2515_L-wide_PUPPI_log10_ecorr': -7.775186053880345,
#  'J1923+2515_L-wide_PUPPI_log10_t2equad': -8.473131426690072,
#  'J1923+2515_red_noise_gamma': 2.349972035868289,
#  'J1923+2515_red_noise_log10_A': -16.869445729553554,
#  'J1944+0907_430_ASP_efac': 0.723098976214611,
#  'J1944+0907_430_ASP_log10_ecorr': -8.351054760229172,
#  'J1944+0907_430_ASP_log10_t2equad': -5.892721926637561,
#  'J1944+0907_430_PUPPI_efac': 1.035000065805881,
#  'J1944+0907_430_PUPPI_log10_ecorr': -8.244816317620533,
#  'J1944+0907_430_PUPPI_log10_t2equad': -6.608735936942311,
#  'J1944+0907_L-wide_ASP_efac': 1.147422018860394,
#  'J1944+0907_L-wide_ASP_log10_ecorr': -6.159055324742069,
#  'J1944+0907_L-wide_ASP_log10_t2equad': -7.947058895694849,
#  'J1944+0907_L-wide_PUPPI_efac': 1.05698722980987,
#  'J1944+0907_L-wide_PUPPI_log10_ecorr': -6.523955511734954,
#  'J1944+0907_L-wide_PUPPI_log10_t2equad': -7.269886040561225,
#  'J1944+0907_S-wide_ASP_efac': 0.729546687337015,
#  'J1944+0907_S-wide_ASP_log10_ecorr': -5.507620687339099,
#  'J1944+0907_S-wide_ASP_log10_t2equad': -7.8312930767308435,
#  'J1944+0907_red_noise_gamma': 1.8561650382412558,
#  'J1944+0907_red_noise_log10_A': -13.27901454906211,
#  'J1946+3417_L-wide_PUPPI_efac': 1.08550494536639,
#  'J1946+3417_L-wide_PUPPI_log10_ecorr': -6.3012894737128375,
#  'J1946+3417_L-wide_PUPPI_log10_t2equad': -8.27131973298902,
#  'J1946+3417_S-wide_PUPPI_efac': 1.015486716863966,
#  'J1946+3417_S-wide_PUPPI_log10_ecorr': -7.867689284336252,
#  'J1946+3417_S-wide_PUPPI_log10_t2equad': -7.108657109424313,
#  'J1946+3417_red_noise_gamma': 1.2471603841759475,
#  'J1946+3417_red_noise_log10_A': -12.54300664903146,
#  'J2010-1323_Rcvr1_2_GASP_efac': 0.868456121294112,
#  'J2010-1323_Rcvr1_2_GASP_log10_ecorr': -8.312436355993654,
#  'J2010-1323_Rcvr1_2_GASP_log10_t2equad': -7.885012931161519,
#  'J2010-1323_Rcvr1_2_GUPPI_efac': 1.01454836531522,
#  'J2010-1323_Rcvr1_2_GUPPI_log10_ecorr': -6.9195464243446185,
#  'J2010-1323_Rcvr1_2_GUPPI_log10_t2equad': -7.991507498741639,
#  'J2010-1323_Rcvr_800_GASP_efac': 0.998451141182614,
#  'J2010-1323_Rcvr_800_GASP_log10_ecorr': -8.463626889747639,
#  'J2010-1323_Rcvr_800_GASP_log10_t2equad': -6.90446599340015,
#  'J2010-1323_Rcvr_800_GUPPI_efac': 0.979882370533329,
#  'J2010-1323_Rcvr_800_GUPPI_log10_ecorr': -7.707228451824862,
#  'J2010-1323_Rcvr_800_GUPPI_log10_t2equad': -7.793728196089243,
#  'J2010-1323_red_noise_gamma': 2.0047699130032304,
#  'J2010-1323_red_noise_log10_A': -16.121940277375323,
#  'J2017+0603_430_PUPPI_efac': 1.036979016861783,
#  'J2017+0603_430_PUPPI_log10_ecorr': -8.028909115973542,
#  'J2017+0603_430_PUPPI_log10_t2equad': -7.449516483055609,
#  'J2017+0603_L-wide_ASP_efac': 1.057336226156642,
#  'J2017+0603_L-wide_ASP_log10_ecorr': -6.674936597115021,
#  'J2017+0603_L-wide_ASP_log10_t2equad': -8.469444170863799,
#  'J2017+0603_L-wide_PUPPI_efac': 1.005817266380866,
#  'J2017+0603_L-wide_PUPPI_log10_ecorr': -7.1630555956005955,
#  'J2017+0603_L-wide_PUPPI_log10_t2equad': -7.849576226290505,
#  'J2017+0603_S-wide_PUPPI_efac': 0.964185095264466,
#  'J2017+0603_S-wide_PUPPI_log10_ecorr': -7.949497485333045,
#  'J2017+0603_S-wide_PUPPI_log10_t2equad': -8.133445843146948,
#  'J2017+0603_red_noise_gamma': 3.0736662544629683,
#  'J2017+0603_red_noise_log10_A': -15.652118248328366,
#  'J2033+1734_430_PUPPI_efac': 0.929484808383487,
#  'J2033+1734_430_PUPPI_log10_ecorr': -5.969820157728044,
#  'J2033+1734_430_PUPPI_log10_t2equad': -5.564416692298268,
#  'J2033+1734_L-wide_PUPPI_efac': 1.069173077532,
#  'J2033+1734_L-wide_PUPPI_log10_ecorr': -8.176589345370358,
#  'J2033+1734_L-wide_PUPPI_log10_t2equad': -7.727867271915852,
#  'J2033+1734_red_noise_gamma': 6.5684233854351115,
#  'J2033+1734_red_noise_log10_A': -16.14468257563011,
#  'J2043+1711_430_ASP_efac': 1.4543608102904,
#  'J2043+1711_430_ASP_log10_ecorr': -8.214322952468054,
#  'J2043+1711_430_ASP_log10_t2equad': -8.63994653050523,
#  'J2043+1711_430_PUPPI_efac': 0.98863262929012,
#  'J2043+1711_430_PUPPI_log10_ecorr': -7.123154371797582,
#  'J2043+1711_430_PUPPI_log10_t2equad': -6.720651512541255,
#  'J2043+1711_L-wide_ASP_efac': 1.116229289530834,
#  'J2043+1711_L-wide_ASP_log10_ecorr': -6.775074389057761,
#  'J2043+1711_L-wide_ASP_log10_t2equad': -8.269934287998842,
#  'J2043+1711_L-wide_PUPPI_efac': 1.015444939548755,
#  'J2043+1711_L-wide_PUPPI_log10_ecorr': -7.69685340162504,
#  'J2043+1711_L-wide_PUPPI_log10_t2equad': -8.156378767962885,
#  'J2043+1711_red_noise_gamma': 3.488308849036269,
#  'J2043+1711_red_noise_log10_A': -17.79813163032176,
#  'J2124-3358_Rcvr1_2_GUPPI_efac': 1.137939222323399,
#  'J2124-3358_Rcvr1_2_GUPPI_log10_ecorr': -8.220410916327268,
#  'J2124-3358_Rcvr1_2_GUPPI_log10_t2equad': -7.516371599402631,
#  'J2124-3358_Rcvr_800_GUPPI_efac': 1.056374773643397,
#  'J2124-3358_Rcvr_800_GUPPI_log10_ecorr': -8.123521593615015,
#  'J2124-3358_Rcvr_800_GUPPI_log10_t2equad': -6.1852671166489515,
#  'J2124-3358_red_noise_gamma': 4.876700799303719,
#  'J2124-3358_red_noise_log10_A': -13.950199507233375,
#  'J2145-0750_Rcvr1_2_GASP_efac': 0.949866468680926,
#  'J2145-0750_Rcvr1_2_GASP_log10_ecorr': -6.837273196205056,
#  'J2145-0750_Rcvr1_2_GASP_log10_t2equad': -5.9606696998049165,
#  'J2145-0750_Rcvr1_2_GUPPI_efac': 1.013154636898133,
#  'J2145-0750_Rcvr1_2_GUPPI_log10_ecorr': -6.291231674117007,
#  'J2145-0750_Rcvr1_2_GUPPI_log10_t2equad': -7.969828800432449,
#  'J2145-0750_Rcvr_800_GASP_efac': 1.137421643486937,
#  'J2145-0750_Rcvr_800_GASP_log10_ecorr': -5.289844107987061,
#  'J2145-0750_Rcvr_800_GASP_log10_t2equad': -6.317638201806473,
#  'J2145-0750_Rcvr_800_GUPPI_efac': 1.015100198939301,
#  'J2145-0750_Rcvr_800_GUPPI_log10_ecorr': -5.943835632678155,
#  'J2145-0750_Rcvr_800_GUPPI_log10_t2equad': -6.473822764827543,
#  'J2145-0750_red_noise_gamma': 1.2367246970925108,
#  'J2145-0750_red_noise_log10_A': -12.930166995114318,
#  'J2214+3000_L-wide_ASP_efac': 1.039356507539033,
#  'J2214+3000_L-wide_ASP_log10_ecorr': -7.635439971631637,
#  'J2214+3000_L-wide_ASP_log10_t2equad': -7.51390992244918,
#  'J2214+3000_L-wide_PUPPI_efac': 1.118177814154822,
#  'J2214+3000_L-wide_PUPPI_log10_ecorr': -6.840834249408872,
#  'J2214+3000_L-wide_PUPPI_log10_t2equad': -7.878408951322362,
#  'J2214+3000_S-wide_PUPPI_efac': 1.0237319013879,
#  'J2214+3000_S-wide_PUPPI_log10_ecorr': -5.997873971846039,
#  'J2214+3000_S-wide_PUPPI_log10_t2equad': -6.30979119807902,
#  'J2214+3000_red_noise_gamma': 1.4245787557586136,
#  'J2214+3000_red_noise_log10_A': -17.123840040975942,
#  'J2229+2643_430_PUPPI_efac': 1.075396502880017,
#  'J2229+2643_430_PUPPI_log10_ecorr': -6.447378690634306,
#  'J2229+2643_430_PUPPI_log10_t2equad': -6.351594824490263,
#  'J2229+2643_L-wide_PUPPI_efac': 1.08540373785908,
#  'J2229+2643_L-wide_PUPPI_log10_ecorr': -7.155983715998768,
#  'J2229+2643_L-wide_PUPPI_log10_t2equad': -7.48871948221686,
#  'J2229+2643_red_noise_gamma': 4.0681871523209,
#  'J2229+2643_red_noise_log10_A': -19.32046348225789,
#  'J2234+0611_430_PUPPI_efac': 0.956496799735073,
#  'J2234+0611_430_PUPPI_log10_ecorr': -8.221999547090622,
#  'J2234+0611_430_PUPPI_log10_t2equad': -6.095495958152848,
#  'J2234+0611_L-wide_PUPPI_efac': 1.002745179368331,
#  'J2234+0611_L-wide_PUPPI_log10_ecorr': -7.5124402071856,
#  'J2234+0611_L-wide_PUPPI_log10_t2equad': -8.136499924059063,
#  'J2234+0611_red_noise_gamma': 2.302140919768435,
#  'J2234+0611_red_noise_log10_A': -13.702570930448056,
#  'J2234+0944_L-wide_PUPPI_efac': 1.06688577327897,
#  'J2234+0944_L-wide_PUPPI_log10_ecorr': -7.195014870163075,
#  'J2234+0944_L-wide_PUPPI_log10_t2equad': -8.428065671538535,
#  'J2234+0944_S-wide_PUPPI_efac': 1.008264680360509,
#  'J2234+0944_S-wide_PUPPI_log10_ecorr': -6.677937406146833,
#  'J2234+0944_S-wide_PUPPI_log10_t2equad': -6.717539069354819,
#  'J2234+0944_red_noise_gamma': 2.2908177397760134,
#  'J2234+0944_red_noise_log10_A': -18.222966652355407,
#  'J2302+4442_Rcvr1_2_GUPPI_efac': 1.040082111861741,
#  'J2302+4442_Rcvr1_2_GUPPI_log10_ecorr': -7.64072102279478,
#  'J2302+4442_Rcvr1_2_GUPPI_log10_t2equad': -7.274863944214771,
#  'J2302+4442_Rcvr_800_GUPPI_efac': 0.993365278821874,
#  'J2302+4442_Rcvr_800_GUPPI_log10_ecorr': -6.096291759572095,
#  'J2302+4442_Rcvr_800_GUPPI_log10_t2equad': -6.903723469421655,
#  'J2302+4442_red_noise_gamma': 0.6864809436960468,
#  'J2302+4442_red_noise_log10_A': -13.161038175925698,
#  'J2317+1439_327_ASP_efac': 1.04320863750764,
#  'J2317+1439_327_ASP_log10_ecorr': -7.487382821111241,
#  'J2317+1439_327_ASP_log10_t2equad': -6.500521375449321,
#  'J2317+1439_327_PUPPI_efac': 1.226791274362784,
#  'J2317+1439_327_PUPPI_log10_ecorr': -8.152395344722127,
#  'J2317+1439_327_PUPPI_log10_t2equad': -6.651902020107133,
#  'J2317+1439_430_ASP_efac': 1.22728486579257,
#  'J2317+1439_430_ASP_log10_ecorr': -6.515470817081663,
#  'J2317+1439_430_ASP_log10_t2equad': -7.101427829548103,
#  'J2317+1439_430_PUPPI_efac': 1.05050697456514,
#  'J2317+1439_430_PUPPI_log10_ecorr': -6.4483868198771335,
#  'J2317+1439_430_PUPPI_log10_t2equad': -6.617399293439907,
#  'J2317+1439_L-wide_PUPPI_efac': 1.03976267616734,
#  'J2317+1439_L-wide_PUPPI_log10_ecorr': -6.237532577063579,
#  'J2317+1439_L-wide_PUPPI_log10_t2equad': -7.381003509278491,
#  'J2317+1439_red_noise_gamma': 3.099555446232068,
#  'J2317+1439_red_noise_log10_A': -19.447753333785272,
#  'J2322+2057_430_PUPPI_efac': 1.020232968411951,
#  'J2322+2057_430_PUPPI_log10_ecorr': -6.203853755020059,
#  'J2322+2057_430_PUPPI_log10_t2equad': -7.730290902034278,
#  'J2322+2057_L-wide_PUPPI_efac': 1.01821429813628,
#  'J2322+2057_L-wide_PUPPI_log10_ecorr': -7.998889712534445,
#  'J2322+2057_L-wide_PUPPI_log10_t2equad': -8.369642510811849,
#  'J2322+2057_S-wide_PUPPI_efac': 0.930792299287725,
#  'J2322+2057_S-wide_PUPPI_log10_ecorr': -7.346426503855777,
#  'J2322+2057_S-wide_PUPPI_log10_t2equad': -8.210845792821688,
#  'J2322+2057_red_noise_gamma': 1.6700333223323403,
#  'J2322+2057_red_noise_log10_A': -17.30323104416495}

# %%
#Setting dataset max time and reference time
maximum = 0
minimum = np.inf
for psr in psrs_total:
    if psr.toas.max() > maximum:
        maximum = psr.toas.max()
    if psr.toas.min() < minimum:
        minimum = psr.toas.min()

#Sets reference time
tref = minimum
print(tref/3600/24/365)
t0_max = (maximum - minimum)/365/24/3600
print(t0_max)

#for psr in psrs_total:
    #print(psr.name)
psrs= [psrs_total[1]]
print(psrs[0].name)
# Out:
# 145.79762127521346
# 16.040756568371524
# B1937+21

# %%
#Number of shape parameter updates
N_slow=int(1e5)

#How often to update fisher matrix proposals (based on shape parameter updates)
n_fish_update = int(N_slow/10)

#Ratio of projection parameter updates per shape parameter update
projection_updates = 10000

#Proposal weights (must sum to 1)
DE_prob = 0.3
fisher_prob = 0.6 
prior_draw_prob = 0.1

#Number of samples to thin (based on total samples N_slow*projection_updates)
thinning = projection_updates

T_max = 4 #2
n_chain = 5 #3

#Prior bounds on shape params
tau_min = 0.05
tau_max = 5.0 #3.0
f_max = 1e-7
f_min = 3.5e-9 #1e-8

#Load in tau scan proposal files
ts_file = "/home/mitch/QuickBurstWork/QuickBurstChoStability/tau_scans/wavelets/PTA_tauscan.pkl"

# resuming_pulsar = 'J0030+0451'
for psr in psrs:
    glitch_ts_file = f"/home/mitch/QuickBurstWork/QuickBurstChoStability/tau_scans/transients/{psr.name}/transients.pkl"
    filepath = "/home/mitch/QuickBurstWork/QuickBurstChoStability/chains/{}/".format(psr.name)
    print('Starting pulsar {}'.format(psr.name))
    os.makedirs(filepath, exist_ok = True)
    savefile = "chain_1"
    savepath = filepath + savefile #NOTE: DO NOT ADD FILE EXTENSION
    
    model_labels = []
    #Tracking run settings
    model_labels.append(["max 0 wavelets ", "max 3 glitches ", "projection_updates/shape_update=10000", "thinning=10000",  "jumps: glitch rj, glitch tau, PT swap, fast, noise", 
                        "noise jump weight (DE, fish, prior) = (0.3,0.6,0.1)"])
    #Prior information
    model_labels.append(["Uniform wavelet amp priors: [-10, -5]"])
    
    with open(filepath+'/run_info.json' , 'w') as fout:
        json.dump(model_labels, fout, sort_keys=True,
                indent=4, separators=(',', ': '))

    #samples, acc_fraction, swap_record, rj_record, ptas, log_likelihood, betas, PT_acc
    _, _, _, _, _, _, _, _ = QuickBurst_MCMC.run_qb(N_slow, T_max, n_chain, [psr,],
                                                                        max_n_wavelet=3,
                                                                        min_n_wavelet=0,
                                                                        n_wavelet_start=0,
                                                                        RJ_weight=1,
                                                                        glitch_RJ_weight=1,
                                                                        regular_weight=1,
                                                                        noise_jump_weight=2,
                                                                        PT_swap_weight=1,
                                                                        tau_scan_proposal_weight=1,
                                                                        glitch_tau_scan_proposal_weight=1,
                                                                        DE_prob = DE_prob,
                                                                        fisher_prob = fisher_prob,
                                                                        prior_draw_prob = prior_draw_prob,
                                                                        de_history_size = 2500,
                                                                        tau_scan_file=ts_file,
                                                                        glitch_tau_scan_file=glitch_ts_file,
                                                                        #gwb_log_amp_range=[-18,-15],
                                                                        rn_log_amp_range=[-18,-11],
                                                                        wavelet_log_amp_range=[-10.0,-5.0],
                                                                        per_psr_rn_log_amp_range=[-18,-11],
                                                                        #rn_params = [noise_params['gw_crn_log10_A'],noise_params['gw_crn_gamma']],
                                                                        prior_recovery=False,
                                                                        #gwb_amp_prior='log-uniform',
                                                                        rn_amp_prior='log-uniform',
                                                                        wavelet_amp_prior='uniform',
                                                                        per_psr_rn_amp_prior='log-uniform',
                                                                        #gwb_on_prior=0.975,
                                                                        max_n_glitch=3,
                                                                        #n_glitch_start='random',
                                                                        glitch_log_amp_range=[-10.0,-5.0],
                                                                        glitch_amp_prior='uniform',
                                                                        f0_max = f_max,
                                                                        f0_min = f_min,
                                                                        tau_max_in = tau_max,
                                                                        tau_min_in = tau_min,
                                                                        t0_max = (psr.toas.max()-minimum)/24/365/3600, #years
                                                                        t0_min = (psr.toas.min()-minimum)/24/365/3600, #years
                                                                        tref = (minimum), #seconds
                                                                        vary_white_noise=True,  
                                                                        include_rn=False, vary_rn=False,
                                                                        include_equad=True,
                                                                        include_ecorr=True,
                                                                        include_efac=True,
                                                                        wn_backend_selection=True,
                                                                        noisedict = noise_params,
                                                                        include_per_psr_rn=True,
                                                                        vary_per_psr_rn=True,
                                                                        # resume_from=savepath,
                                                                        #per_psr_rn_start_file=RN_start_file,
                                                                        n_fish_update = n_fish_update,
                                                                        savepath=savepath, save_every_n=100,
                                                                        n_fast_to_slow=projection_updates, thin = thinning)
# Out:
# Starting pulsar B1937+21
# Number of params per pulsar:  [26]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 51
#      47     json.dump(model_labels, fout, sort_keys=True,
#      48             indent=4, separators=(',', ': '))
#      50 #samples, acc_fraction, swap_record, rj_record, ptas, log_likelihood, betas, PT_acc
# ---> 51 _, _, _, _, _, _, _, _ = QuickBurst_MCMC.run_qb(N_slow, T_max, n_chain, [psr,],
#      52                                                                     max_n_wavelet=0,
#      53                                                                     min_n_wavelet=0,
#      54                                                                     n_wavelet_start=0,
#      55                                                                     RJ_weight=0,
#      56                                                                     glitch_RJ_weight=1,
#      57                                                                     regular_weight=1,
#      58                                                                     noise_jump_weight=2,
#      59                                                                     PT_swap_weight=1,
#      60                                                                     tau_scan_proposal_weight=0,
#      61                                                                     glitch_tau_scan_proposal_weight=1,
#      62                                                                     DE_prob = DE_prob,
#      63                                                                     fisher_prob = fisher_prob,
#      64                                                                     prior_draw_prob = prior_draw_prob,
#      65                                                                     de_history_size = 2500,
#      66                                                                     tau_scan_file=ts_file,
#      67                                                                     glitch_tau_scan_file=glitch_ts_file,
#      68                                                                     #gwb_log_amp_range=[-18,-15],
#      69                                                                     rn_log_amp_range=[-18,-11],
#      70                                                                     wavelet_log_amp_range=[-10.0,-5.0],
#      71                                                                     per_psr_rn_log_amp_range=[-18,-11],
#      72                                                                     #rn_params = [noise_params['gw_crn_log10_A'],noise_params['gw_crn_gamma']],
#      73                                                                     prior_recovery=False,
#      74                                                                     #gwb_amp_prior='log-uniform',
#      75                                                                     rn_amp_prior='log-uniform',
#      76                                                                     wavelet_amp_prior='uniform',
#      77                                                                     per_psr_rn_amp_prior='log-uniform',
#      78                                                                     #gwb_on_prior=0.975,
#      79                                                                     max_n_glitch=3,
#      80                                                                     #n_glitch_start='random',
#      81                                                                     glitch_log_amp_range=[-10.0,-5.0],
#      82                                                                     glitch_amp_prior='uniform',
#      83                                                                     f0_max = f_max,
#      84                                                                     f0_min = f_min,
#      85                                                                     tau_max_in = tau_max,
#      86                                                                     tau_min_in = tau_min,
#      87                                                                     t0_max = (psr.toas.max()-minimum)/24/365/3600, #years
#      88                                                                     t0_min = (psr.toas.min()-minimum)/24/365/3600, #years
#      89                                                                     tref = (minimum), #seconds
#      90                                                                     vary_white_noise=True,
#      91                                                                     include_rn=False, vary_rn=False,
#      92                                                                     include_equad=True,
#      93                                                                     include_ecorr=True,
#      94                                                                     include_efac=True,
#      95                                                                     wn_backend_selection=True,
#      96                                                                     noisedict = noise_params,
#      97                                                                     include_per_psr_rn=True,
#      98                                                                     vary_per_psr_rn=True,
#      99                                                                     # resume_from=savepath,
#     100                                                                     #per_psr_rn_start_file=RN_start_file,
#     101                                                                     n_fish_update = n_fish_update,
#     102                                                                     savepath=savepath, save_every_n=100,
#     103                                                                     n_fast_to_slow=projection_updates, thin = thinning)
#
# File ~/QuickBurstWork/QuickBurstChoStability/QuickBurst/QuickBurst_MCMC.py:218, in run_qb(N_slow, T_max, n_chain, pulsars, max_n_wavelet, min_n_wavelet, n_wavelet_prior, n_wavelet_start, RJ_weight, glitch_RJ_weight, regular_weight, noise_jump_weight, PT_swap_weight, DE_prob, fisher_prob, prior_draw_prob, de_history_size, thin_de, T_ladder, T_dynamic, T_dynamic_nu, T_dynamic_t0, PT_hist_length, tau_scan_proposal_weight, glitch_tau_scan_proposal_weight, tau_scan_file, prior_recovery, wavelet_amp_prior, rn_amp_prior, per_psr_rn_amp_prior, rn_log_amp_range, per_psr_rn_log_amp_range, wavelet_log_amp_range, vary_white_noise, efac_start, include_equad, include_ecorr, include_efac, wn_backend_selection, noisedict, include_rn, vary_rn, rn_params, include_per_psr_rn, vary_per_psr_rn, per_psr_rn_start_file, jupyter_notebook, max_n_glitch, glitch_amp_prior, glitch_log_amp_range, equad_range, ecorr_range, n_glitch_prior, n_glitch_start, t0_min, t0_max, tref, glitch_tau_scan_file, TF_prior_file, f0_min, f0_max, tau_min_in, tau_max_in, save_every_n, savepath, resume_from, start_from, n_status_update, n_fish_update, n_fast_to_slow, thin)
#     216     with open(TF_prior_file, 'rb') as f:
#     217         TF_prior = pickle.load(f)
# --> 218 pta, QB_FP, QB_FPI, glitch_indx, wavelet_indx, per_puls_indx, per_puls_rn_indx, per_puls_wn_indx, rn_indx, all_noiseparam_idxs, num_per_puls_param_list = get_pta(pulsars, vary_white_noise=vary_white_noise, include_equad=include_equad,
#     219                                                                                                 include_ecorr = include_ecorr, include_efac = include_efac,
#     220                                                                                                 wn_backend_selection=wn_backend_selection,noisedict=noisedict, include_rn=include_rn, vary_rn=vary_rn,
#     221                                                                                                 include_per_psr_rn=include_per_psr_rn, vary_per_psr_rn=vary_per_psr_rn,
#     222                                                                                                 max_n_wavelet=max_n_wavelet, efac_start=efac_start, rn_amp_prior=rn_amp_prior,
#     223                                                                                                 rn_log_amp_range=rn_log_amp_range, rn_params=rn_params, per_psr_rn_amp_prior=per_psr_rn_amp_prior,
#     224                                                                                                 per_psr_rn_log_amp_range=per_psr_rn_log_amp_range, equad_range = equad_range,
#     225                                                                                                 wavelet_amp_prior=wavelet_amp_prior, ecorr_range = ecorr_range,
#     226                                                                                                 wavelet_log_amp_range=wavelet_log_amp_range, prior_recovery=prior_recovery,
#     227                                                                                                 max_n_glitch=max_n_glitch, glitch_amp_prior=glitch_amp_prior, glitch_log_amp_range=glitch_log_amp_range,
#     228                                                                                                 t0_min=t0_min, t0_max=t0_max, f0_min=f0_min, f0_max=f0_max, tau_min=tau_min_in, tau_max=tau_max_in,
#     229                                                                                                 TF_prior=TF_prior, tref=tref)
#     232 print('all noise param indexes: {}'.format(all_noiseparam_idxs))
#     233 if n_chain < 2:
#
# File ~/QuickBurstWork/QuickBurstChoStability/QuickBurst/QuickBurst_MCMC.py:2879, in get_pta(pulsars, vary_white_noise, include_equad, include_ecorr, include_efac, wn_backend_selection, noisedict, include_rn, vary_rn, include_per_psr_rn, vary_per_psr_rn, max_n_wavelet, efac_start, rn_amp_prior, rn_log_amp_range, rn_params, wavelet_amp_prior, wavelet_log_amp_range, per_psr_rn_amp_prior, per_psr_rn_log_amp_range, equad_range, ecorr_range, prior_recovery, max_n_glitch, glitch_amp_prior, glitch_log_amp_range, t0_min, t0_max, f0_min, f0_max, tau_min, tau_max, TF_prior, use_svd_for_timing_gp, tref)
#    2877 #Generate the lnPrior object for this PTA
#    2878 QB_FP = QB_FastPrior.FastPrior(pta, pulsars)
# -> 2879 QB_FPI = QB_FastPrior.get_FastPriorInfo(pta, pulsars, max_n_glitch, max_n_wavelet)
#    2881 rn_indx = np.zeros((2), dtype = 'int')
#    2882 if vary_rn:
#
# File ~/QuickBurstWork/QuickBurstChoStability/QuickBurst/QB_FastPrior.py:642, in get_FastPriorInfo(pta, psrs, max_n_glitch, max_n_wavelet)
#     640 """get FastPriorInfo object from pta"""
#     641 fp_loc = FastPrior(pta,psrs)
# --> 642 FPI = FastPriorInfo(fp_loc.uniform_par_ids, fp_loc.uniform_lows, fp_loc.uniform_highs,\
#     643                     fp_loc.lin_exp_par_ids, fp_loc.lin_exp_lows, fp_loc.lin_exp_highs,\
#     644                     fp_loc.normal_par_ids, fp_loc.normal_mus, fp_loc.normal_sigs,\
#     645                     fp_loc.dm_par_ids, fp_loc.dm_dists, fp_loc.dm_errs,\
#     646                     fp_loc.px_par_ids, fp_loc.px_mus, fp_loc.px_errs,\
#     647                     fp_loc.cut_par_ids,fp_loc.cut_lows,fp_loc.cut_highs, \
#     648                     fp_loc.global_common, fp_loc.glitch_uf_par_ids, fp_loc.glitch_uf_lows, \
#     649                     fp_loc.glitch_uf_highs, fp_loc.glitch_le_par_ids, \
#     650                     fp_loc.glitch_le_lows, fp_loc.glitch_le_highs, \
#     651                     fp_loc.wave_uf_par_ids, fp_loc.wave_uf_lows,\
#     652                     fp_loc.wave_uf_highs, fp_loc.wave_le_par_ids,\
#     653                     fp_loc.wave_le_lows, fp_loc.wave_le_highs, max_n_wavelet,\
#     654                     max_n_glitch, max_n_wavelet, max_n_glitch)
#     655 return FPI
#
# File ~/miniconda3/envs/QuickBurst/lib/python3.9/site-packages/numba/experimental/jitclass/base.py:124, in JitClassType.__call__(cls, *args, **kwargs)
#     122 bind = cls._ctor_sig.bind(None, *args, **kwargs)
#     123 bind.apply_defaults()
# --> 124 return cls._ctor(*bind.args[1:], **bind.kwargs)
#
# File ~/miniconda3/envs/QuickBurst/lib/python3.9/site-packages/numba/core/dispatcher.py:375, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     373 return_val = None
#     374 try:
# --> 375     return_val = self.compile(tuple(argtypes))
#     376 except errors.ForceLiteralArg as e:
#     377     # Received request for compiler re-entry with the list of arguments
#     378     # indicated by e.requested_args.
#     379     # First, check if any of these args are already Literal-ized
#     380     already_lit_pos = [i for i in e.requested_args
#     381                        if isinstance(args[i], types.Literal)]
#
# File ~/miniconda3/envs/QuickBurst/lib/python3.9/site-packages/numba/core/dispatcher.py:905, in Dispatcher.compile(self, sig)
#     903 with ev.trigger_event("numba:compile", data=ev_details):
#     904     try:
# --> 905         cres = self._compiler.compile(args, return_type)
#     906     except errors.ForceLiteralArg as e:
#     907         def folded(args, kws):
#
# File ~/miniconda3/envs/QuickBurst/lib/python3.9/site-packages/numba/core/dispatcher.py:80, in _FunctionCompiler.compile(self, args, return_type)
#      79 def compile(self, args, return_type):
# ---> 80     status, retval = self._compile_cached(args, return_type)
#      81     if status:
#      82         return retval
#
# File ~/miniconda3/envs/QuickBurst/lib/python3.9/site-packages/numba/core/dispatcher.py:94, in _FunctionCompiler._compile_cached(self, args, return_type)
#      91     pass
#      93 try:
# ---> 94     retval = self._compile_core(args, return_type)
#      95 except errors.TypingError as e:
#      96     self._failed_cache[key] = e
#
# File ~/miniconda3/envs/QuickBurst/lib/python3.9/site-packages/numba/core/dispatcher.py:107, in _FunctionCompiler._compile_core(self, args, return_type)
#     104 flags = self._customize_flags(flags)
#     106 impl = self._get_implementation(args, {})
# --> 107 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     108                               self.targetdescr.target_context,
#     109                               impl,
#     110                               args=args, return_type=return_type,
#     111                               flags=flags, locals=self.locals,
#     112                               pipeline_class=self.pipeline_class)
#     113 # Check typing error if object mode is used
#     114 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File ~/miniconda3/envs/QuickBurst/lib/python3.9/site-packages/numba/core/compiler.py:744, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     720 """Compiler entry point
#     721
#     722 Parameter
#    (...)
#     740     compiler pipeline
#     741 """
#     742 pipeline = pipeline_class(typingctx, targetctx, library,
#     743                           args, return_type, flags, locals)
# --> 744 return pipeline.compile_extra(func)
#
# File ~/miniconda3/envs/QuickBurst/lib/python3.9/site-packages/numba/core/compiler.py:438, in CompilerBase.compile_extra(self, func)
#     436 self.state.lifted = ()
#     437 self.state.lifted_from = None
# --> 438 return self._compile_bytecode()
#
# File ~/miniconda3/envs/QuickBurst/lib/python3.9/site-packages/numba/core/compiler.py:506, in CompilerBase._compile_bytecode(self)
#     502 """
#     503 Populate and run pipeline for bytecode input
#     504 """
#     505 assert self.state.func_ir is None
# --> 506 return self._compile_core()
#
# File ~/miniconda3/envs/QuickBurst/lib/python3.9/site-packages/numba/core/compiler.py:472, in CompilerBase._compile_core(self)
#     470 res = None
#     471 try:
# --> 472     pm.run(self.state)
#     473     if self.state.cr is not None:
#     474         break
#
# File ~/miniconda3/envs/QuickBurst/lib/python3.9/site-packages/numba/core/compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File ~/miniconda3/envs/QuickBurst/lib/python3.9/site-packages/numba/core/compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/QuickBurst/lib/python3.9/site-packages/numba/core/compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File ~/miniconda3/envs/QuickBurst/lib/python3.9/site-packages/numba/core/compiler_machinery.py:273, in PassManager._runPass.<locals>.check(func, compiler_state)
#     272 def check(func, compiler_state):
# --> 273     mangled = func(compiler_state)
#     274     if mangled not in (True, False):
#     275         msg = ("CompilerPass implementations should return True/False. "
#     276                "CompilerPass with name '%s' did not.")
#
# File ~/miniconda3/envs/QuickBurst/lib/python3.9/site-packages/numba/core/typed_passes.py:497, in BaseNativeLowering.run_pass(self, state)
#     491     state['cr'] = _LowerResult(fndesc, call_helper,
#     492                                cfunc=None, env=env)
#     493 else:
#     494     # Prepare for execution
#     495     # Insert native function for use by other jitted-functions.
#     496     # We also register its library to allow for inlining.
# --> 497     cfunc = targetctx.get_executable(library, fndesc, env)
#     498     targetctx.insert_user_function(cfunc, fndesc, [library])
#     499     state['cr'] = _LowerResult(fndesc, call_helper,
#     500                                cfunc=cfunc, env=env)
#
# File ~/miniconda3/envs/QuickBurst/lib/python3.9/site-packages/numba/core/cpu.py:239, in CPUContext.get_executable(self, library, fndesc, env)
#     226 """
#     227 Returns
#     228 -------
#    (...)
#     236     an execution environment (from _dynfunc)
#     237 """
#     238 # Code generation
# --> 239 fnptr = library.get_pointer_to_function(
#     240     fndesc.llvm_cpython_wrapper_name)
#     242 # Note: we avoid reusing the original docstring to avoid encoding
#     243 # issues on Python 2, see issue #1908
#     244 doc = "compiled wrapper for %r" % (fndesc.qualname,)
#
# File ~/miniconda3/envs/QuickBurst/lib/python3.9/site-packages/numba/core/codegen.py:989, in JITCodeLibrary.get_pointer_to_function(self, name)
#     975 def get_pointer_to_function(self, name):
#     976     """
#     977     Generate native code for function named *name* and return a pointer
#     978     to the start of the function (as an integer).
#    (...)
#     987         - non-zero if the symbol is defined.
#     988     """
# --> 989     self._ensure_finalized()
#     990     ee = self._codegen._engine
#     991     if not ee.is_symbol_defined(name):
#
# File ~/miniconda3/envs/QuickBurst/lib/python3.9/site-packages/numba/core/codegen.py:567, in CodeLibrary._ensure_finalized(self)
#     565 def _ensure_finalized(self):
#     566     if not self._finalized:
# --> 567         self.finalize()
#
# File ~/miniconda3/envs/QuickBurst/lib/python3.9/site-packages/numba/core/codegen.py:762, in CPUCodeLibrary.finalize(self)
#     756         self._final_module.link_in(
#     757             library._get_module_for_linking(), preserve=True,
#     758         )
#     760 # Optimize the module after all dependences are linked in above,
#     761 # to allow for inlining.
# --> 762 self._optimize_final_module()
#     764 self._final_module.verify()
#     765 self._finalize_final_module()
#
# File ~/miniconda3/envs/QuickBurst/lib/python3.9/site-packages/numba/core/codegen.py:682, in CPUCodeLibrary._optimize_final_module(self)
#     679 full_name = "Module passes (full optimization)"
#     680 with self._recorded_timings.record(full_name):
#     681     # The full optimisation suite is then run on the refop pruned IR
# --> 682     self._codegen._mpm_full.run(self._final_module)
#
# File ~/miniconda3/envs/QuickBurst/lib/python3.9/site-packages/llvmlite/binding/passmanagers.py:698, in ModulePassManager.run(self, module, remarks_file, remarks_format, remarks_filter)
#     683 """
#     684 Run optimization passes on the given module.
#     685
#    (...)
#     695     The filter that should be applied to the remarks output.
#     696 """
#     697 if remarks_file is None:
# --> 698     return ffi.lib.LLVMPY_RunPassManager(self, module)
#     699 else:
#     700     r = ffi.lib.LLVMPY_RunPassManagerWithRemarks(
#     701         self, module, _encode_string(remarks_format),
#     702         _encode_string(remarks_filter),
#     703         _encode_string(remarks_file))
#
# File ~/miniconda3/envs/QuickBurst/lib/python3.9/site-packages/llvmlite/binding/ffi.py:192, in _lib_fn_wrapper.__call__(self, *args, **kwargs)
#     190 def __call__(self, *args, **kwargs):
#     191     with self._lock:
# --> 192         return self._cfn(*args, **kwargs)
#
# KeyboardInterrupt:
